# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
adult_df = pd.read_csv(r"C:\Users\ajink\OneDrive\Desktop\Mom Visa\adult.csv")
print("number of observations",adult_df.shape)
adult_df.head
# Out:
# number of observations (32561, 15)
# <bound method NDFrame.head of        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
adult_df.describe
# Out:
# <bound method NDFrame.describe of        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
categorical_data = adult_df.dtypes[adult_df.dtypes == "object"]
numerical_data = adult_df.dtypes[adult_df.dtypes != "object"]

# %%
for da in list(categorical_data.index):
    print(f"-------------------{da.title()}-------------------------")
    total = adult_df[da].value_counts()
    percent = adult_df[da].value_counts()/ adult_df.shape[0]
    df = pd.concat([total,percent],keys=['total','percent'],axis = 1 )
    print(df)
    print('\n')
# Out:
# -------------------Workclass-------------------------
#                    total   percent
#  Private           22696  0.697030
#  Self-emp-not-inc   2541  0.078038
#  Local-gov          2093  0.064279
#  ?                  1836  0.056386
#  State-gov          1298  0.039864
#  Self-emp-inc       1116  0.034274
#  Federal-gov         960  0.029483
#  Without-pay          14  0.000430
#  Never-worked          7  0.000215
#
#
# -------------------Education-------------------------
#                total   percent
#  HS-grad       10501  0.322502
#  Some-college   7291  0.223918
#  Bachelors      5355  0.164461
#  Masters        1723  0.052916
#  Assoc-voc      1382  0.042443
#  11th           1175  0.036086
#  Assoc-acdm     1067  0.032769
#  10th            933  0.028654
#  7th-8th         646  0.019840
#  Prof-school     576  0.017690
#  9th             514  0.015786
#  12th            433  0.013298
#  Doctorate       413  0.012684
#  5th-6th         333  0.010227
# ...

# %%
edit_column = ['country','occupation','workclass']
for da in edit_column:
    adult_df.loc[adult_df[da] == '?', da ] = 'unknown'

# %%
high_sch = ['HS-grad','11th','10th','9th','12th']
elementary = ['1st-4th','5th-6th','7th-8th']
adult_df['education'].replace(to_replace = hs_grad,value = 'HS-grad')
